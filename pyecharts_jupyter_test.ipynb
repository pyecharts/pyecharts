# %%
# %pylab inline
import pandas as pd
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <h1>Hello, world!</h1>

# %%
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子", "ddd"], [5, 20, 36, 10, 75, 90,60])
HTML(bar.render2())
# Out:
#         <div id="2017-07-24 18:19:36.176214" style="width:800px; height:600px;"></div>
#         <script>
#             require.config({
#                  paths:{
#                     echarts: '//cdn.bootcss.com/echarts/3.2.3/echarts.min',
#                     china: '//echarts.baidu.com/gallery/vendors/echarts/map/js/china',
#                  }
#             });
#             require(['echarts','china'],function(ec){
#             var myChart = ec.init(document.getElementById('2017-07-24 18:19:36.176214'));
#                        var option =  {
#     "xAxis": {
#         "nameLocation": "middle",
#         "nameGap": 25,
#         "name": "",
#         "type": "category",
#         "axisLabel": {
#             "interval": "auto"
#         },
#         "data": [
#             "\u886c\u886b",
#             "\u7f8a\u6bdb\u886b",
#             "\u96ea\u7eba\u886b",
#             "\u88e4\u5b50",
#             "\u9ad8\u8ddf\u978b",
#             "\u889c\u5b50",
#             "ddd"
# ...
