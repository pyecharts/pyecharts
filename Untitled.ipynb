# %%
from pyecharts.globals import CurrentConfig
CurrentConfig.NOTEBOOK_TYPE = "jupyter_lab"

from example.commons import Collector, Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Page

c = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    )
c
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="8c4f3cbb3d514a0e981e51834b06e6b7" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_8c4f3cbb3d514a0e981e51834b06e6b7 = echarts.init(
#             document.getElementById('8c4f3cbb3d514a0e981e51834b06e6b7'), 'white', {renderer: 'canvas'});
#         var option_8c4f3cbb3d514a0e981e51834b06e6b7 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
# ...

# %%
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="cc129fa72b59489e81c9e380424aae5a" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_cc129fa72b59489e81c9e380424aae5a = echarts.init(
#             document.getElementById('cc129fa72b59489e81c9e380424aae5a'), 'white', {renderer: 'canvas'});
#         var option_cc129fa72b59489e81c9e380424aae5a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
# ...

# %%
class A:
    def _repr_html_(self):
        return "<div>hello world</div>"

a = A()

# %%
a
# Out:
# <div>hello world</div>

# %%
class A:
    def _repr_html_(self):
        return """<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8">
</head>
<body>
        <div id="cc129fa72b59489e81c9e380424aae5a" style="width:900px; height:500px;"></div>
    <script>
        var chart_cc129fa72b59489e81c9e380424aae5a = echarts.init(
            document.getElementById('cc129fa72b59489e81c9e380424aae5a'), 'white', {renderer: 'canvas'});
        var option_cc129fa72b59489e81c9e380424aae5a = {
    "color": [
        "#c23531",
        "#2f4554",
        "#61a0a8",
        "#d48265",
        "#749f83",
        "#ca8622",
        "#bda29a",
        "#6e7074",
        "#546570",
        "#c4ccd3",
        "#f05b72",
        "#ef5b9c",
        "#f47920",
        "#905a3d",
        "#fab27b",
        "#2a5caa",
        "#444693",
        "#726930",
        "#b2d235",
        "#6d8346",
        "#ac6767",
        "#1d953f",
        "#6950a1",
        "#918597"
    ],
    "series": [
        {
            "type": "bar",
            "name": "\u5546\u5bb6A",
            "data": [
                48,
                63,
                85,
                94,
                147,
                28,
                60
            ],
            "barCategoryGap": "20%",
            "label": {
                "show": true,
                "position": "top",
                "fontSize": 12
            }
        },
        {
            "type": "bar",
            "name": "\u5546\u5bb6B",
            "data": [
                59,
                58,
                94,
                114,
                54,
                55,
                91
            ],
            "barCategoryGap": "20%",
            "label": {
                "show": true,
                "position": "top",
                "fontSize": 12
            }
        }
    ],
    "legend": [
        {
            "data": [
                "\u5546\u5bb6A",
                "\u5546\u5bb6B"
            ],
            "show": true
        }
    ],
    "tooltip": {
        "trigger": "item",
        "triggerOn": "mousemove|click",
        "axisPointer": {
            "type": "line"
        },
        "textStyle": {
            "fontSize": 14
        },
        "borderWidth": 0
    },
    "yAxis": [
        {
            "show": true,
            "scale": false,
            "nameLocation": "end",
            "nameGap": 15,
            "gridIndex": 0,
            "axisTick": {},
            "axisLabel": {},
            "splitLine": {
                "show": false,
                "lineStyle": {
                    "width": 1,
                    "opacity": 1,
                    "curveness": 0,
                    "type": "solid"
                }
            },
            "axisLine": {
                "lineStyle": {
                    "width": 1,
                    "opacity": 1,
                    "curveness": 0,
                    "type": "solid"
                }
            }
        }
    ],
    "xAxis": [
        {
            "show": true,
            "scale": false,
            "nameLocation": "end",
            "nameGap": 15,
            "gridIndex": 0,
            "axisTick": {},
            "axisLabel": {},
            "splitLine": {
                "show": false,
                "lineStyle": {
                    "width": 1,
                    "opacity": 1,
                    "curveness": 0,
                    "type": "solid"
                }
            },
            "axisLine": {
                "lineStyle": {
                    "width": 1,
                    "opacity": 1,
                    "curveness": 0,
                    "type": "solid"
                }
            },
            "data": [
                "\u8349\u8393",
                "\u8292\u679c",
                "\u8461\u8404",
                "\u96ea\u68a8",
                "\u897f\u74dc",
                "\u67e0\u6aac",
                "\u8f66\u5398\u5b50"
            ]
        }
    ],
    "title": [
        {
            "text": "Bar-\u57fa\u672c\u793a\u4f8b",
            "subtext": "\u6211\u662f\u526f\u6807\u9898"
        }
    ]
};
        chart_cc129fa72b59489e81c9e380424aae5a.setOption(option_cc129fa72b59489e81c9e380424aae5a);
    </script>
</body>
</html>"""

a = A()

# %%
a
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="cc129fa72b59489e81c9e380424aae5a" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_cc129fa72b59489e81c9e380424aae5a = echarts.init(
#             document.getElementById('cc129fa72b59489e81c9e380424aae5a'), 'white', {renderer: 'canvas'});
#         var option_cc129fa72b59489e81c9e380424aae5a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
# ...
