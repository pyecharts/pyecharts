# %%
from example.commons import Collector, Faker
from pyecharts import options as opts
from pyecharts.charts import Map, Page
from pyecharts.datasets import register

register('https://echarts-maps.github.io/echarts-china-counties-js')


m=(Map()
        .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "凤庆县")
        .set_global_opts(title_opts=opts.TitleOpts(title="Map-基本示例"))
  )
m
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://assets.pyecharts.org/assets/echarts.min', '凤庆县':'https://echarts-maps.github.io/echarts-china-counties-js/echarts-china-counties-js/21a3ab5f2330c5527505699545048156'
#         }
#     });
# </script>
#
#     <div id="5efec802281f42819fdc922fa92b1480" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', '凤庆县'], function(echarts) {
#         var chart_5efec802281f42819fdc922fa92b1480 = echarts.init(
#             document.getElementById('5efec802281f42819fdc922fa92b1480'), 'white', {renderer: 'canvas'});
#         var option_5efec802281f42819fdc922fa92b1480 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "fontSize": 12
#             },
#             "mapType": "\u51e4\u5e86\u53bf",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 109
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 103
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#         chart_5efec802281f42819fdc922fa92b1480.setOption(option_5efec802281f42819fdc922fa92b1480);
#     });
# </script>
