# %%
from pyecharts import Map

value = [20, 190, 253, 77, 65]
attr = ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市']
map = Map("广东地图示例", width=1200, height=600)
map.add("", attr, value, maptype='广东', is_visualmap=True, visual_text_color='#000')
map
# Out:
# <div id="2017-08-02 09:04:16.952124" style="width:1200px; height:600px;"></div>
# <script>
#     require.config({
#          paths:{
#             echarts: '//cdn.bootcss.com/echarts/3.6.2/echarts.min',
#             china: '//echarts.baidu.com/gallery/vendors/echarts/map/js/china'
# , guangdong: '//oog4yfyu0.bkt.clouddn.com/guangdong'          }
#     });
#     require(['echarts', 'china' , 'guangdong'],function(ec){
#     var myChart = ec.init(document.getElementById('2017-08-02 09:04:16.952124'));
#                var option =  {
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "selectedMode": "multiple",
#             "data": [
#                 ""
#             ],
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series": [
#         {
#             "name": "",
#             "type": "map",
#             "symbol": "circle",
#             "roam": true,
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 190
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 65
#                 }
#             ],
#             "mapType": "\u5e7f\u4e1c"
#         }
#     ],
#     "_index_flag": 1790848,
#     "title": [
#         {
#             "text": "\u5e7f\u4e1c\u5730\u56fe\u793a\u4f8b",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "",
#             "top": "auto",
#             "left": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             }
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true
#             }
#         },
#         "show": true,
#         "left": "right",
#         "orient": "vertical",
#         "top": "center"
#     },
#     "tooltip": {},
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "top": "bottom",
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "type": "continuous",
#         "calculable": true,
#         "orient": "vertical",
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": "#000"
#         },
#         "max": 100,
#         "left": "left",
#         "min": 0
#     },
#     "backgroundColor": "#fff"
# };
#                myChart.setOption(option);
#     });
# </script>

# %%
value = [155, 10, 66, 78]
attr = ["福建", "山东", "北京", "上海"]
map = Map("全国地图示例", width=1200, height=600)
map.add("", attr, value, maptype='china')
map
# Out:
# <div id="2017-08-02 09:04:16.968634" style="width:1200px; height:600px;"></div>
# <script>
#     require.config({
#          paths:{
#             echarts: '//cdn.bootcss.com/echarts/3.6.2/echarts.min',
#             china: '//echarts.baidu.com/gallery/vendors/echarts/map/js/china'
#          }
#     });
#     require(['echarts', 'china' ],function(ec){
#     var myChart = ec.init(document.getElementById('2017-08-02 09:04:16.968634'));
#                var option =  {
#     "legend": [
#         {
#             "show": true,
#             "orient": "horizontal",
#             "selectedMode": "multiple",
#             "data": [
#                 ""
#             ],
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series": [
#         {
#             "name": "",
#             "type": "map",
#             "symbol": "circle",
#             "roam": true,
#             "data": [
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 78
#                 }
#             ],
#             "mapType": "china"
#         }
#     ],
#     "_index_flag": 1279992,
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5730\u56fe\u793a\u4f8b",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "",
#             "top": "auto",
#             "left": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             }
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true
#             }
#         },
#         "show": true,
#         "left": "right",
#         "orient": "vertical",
#         "top": "center"
#     },
#     "tooltip": {},
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "backgroundColor": "#fff"
# };
#                myChart.setOption(option);
#     });
# </script>

# %%
from pyecharts import WordCloud

name = ['Sam S Club', 'Macys', 'Amy Schumer', 'Jurassic World', 'Charter Communications',
        'Chick Fil A', 'Planet Fitness', 'Pitch Perfect', 'Express', 'Home', 'Johnny Depp',
        'Lena Dunham', 'Lewis Hamilton', 'KXAN', 'Mary Ellen Mark', 'Farrah Abraham',
        'Rita Ora', 'Serena Williams', 'NCAA baseball tournament', 'Point Break']
value = [10000, 6181, 4386, 4055, 2467, 2244, 1898, 1484, 1112, 965, 847, 582, 555,
         550, 462, 366, 360, 282, 273, 265]
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <body>
#     <style>
#         html,
#         body,
#         # 2017-08-02 09:04:16.996640 {
#             width: 100%;
#             height: 100%;
#             margin: 0;
#         }
#     </style>
# <div id="2017-08-02 09:04:16.996640" style="width:1300px; height:620px;"></div>
# <script>
#     require.config({
#         paths:{
#         echarts: '//cdn.bootcss.com/echarts/3.2.2/echarts.simple',
#         wordCloud: '//data-visual.cn/datav/src/js/echarts/extension/echarts-wordcloud.min'
#         }
#     });
#     require(['echarts','wordCloud'],function(ec){
#     var myChart = ec.init(document.getElementById('2017-08-02 09:04:16.996640'));
#             var option =  {
#     "legend": [
#         {
#             "data": []
#         }
#     ],
#     "series": [
#         {
#             "name": "",
#             "type": "wordCloud",
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,48,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,88,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,108,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,131,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,104,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,86,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1898,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,120,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,77,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,39,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 965,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,124,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,137,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,106,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,133,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,105,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,87,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,0,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,57,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,64,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,143,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,38,53)"
#                         }
#                     }
#                 }
#             ],
#             "shape": "circle",
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20
#         }
#     ],
#     "_index_flag": 1470403,
#     "title": [
#         {
#             "text": "",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "",
#             "top": "auto",
#             "left": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             }
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true
#             }
#         },
#         "show": true,
#         "left": "right",
#         "orient": "vertical",
#         "top": "center"
#     },
#     "tooltip": {},
#     "backgroundColor": "#fff"
# };
#             myChart.setOption(option);
#     });
# </script>
# </body>

# %%
from pyecharts import Liquid

liquid = Liquid("水球图示例")
liquid.add("Liquid", [0.6])

liquid
# Out:
# <div id="2017-08-02 09:04:17.011663" style="width:800px; height:400px;"></div>
# <script>
#     require.config({
#          paths:{
#            echarts: '//cdn.bootcss.com/echarts/3.2.2/echarts',
#            liquidFill: '//oog4yfyu0.bkt.clouddn.com/liquidfill'
#          }
#     });
#     require(['echarts','liquidFill'],function(ec){
#     var myChart = ec.init(document.getElementById('2017-08-02 09:04:17.011663'));
#                var option =  {
#     "legend": [
#         {
#             "data": []
#         }
#     ],
#     "series": [
#         {
#             "name": "Liquid",
#             "animationDurationUpdate": 1000,
#             "type": "liquidFill",
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "data": [
#                 0.6
#             ],
#             "outline": {
#                 "show": true
#             }
#         }
#     ],
#     "_index_flag": 1231265,
#     "title": [
#         {
#             "text": "\u6c34\u7403\u56fe\u793a\u4f8b",
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             },
#             "subtext": "",
#             "top": "auto",
#             "left": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             }
#         }
#     ],
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true
#             }
#         },
#         "show": true,
#         "left": "right",
#         "orient": "vertical",
#         "top": "center"
#     },
#     "tooltip": {},
#     "backgroundColor": "#fff"
# };
#                myChart.setOption(option);
#     });
# </script>
