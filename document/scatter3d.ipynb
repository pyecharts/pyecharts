# %%
from pyecharts import Scatter3D

import random
data = [[random.randint(0, 100), random.randint(0, 100), random.randint(0, 100)] for _ in range(80)]
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
scatter3D = Scatter3D("3D 散点图示例", width=1200, height=600)
scatter3D.add("", data, is_visualmap=True, visual_range_color=range_color)
scatter3D
# Out:
# <div id="2017-08-03 09:58:10.844299" style="width:1200px; height:600px;"></div>
# <script>
#     require.config({
#          paths:{
#             echarts: '//oog4yfyu0.bkt.clouddn.com/echarts.min',
#             echartsgl: '//oog4yfyu0.bkt.clouddn.com/echarts-gl',
#             china: '//echarts.baidu.com/gallery/vendors/echarts/map/js/china',
#          }
#     });
#     require(['echarts', 'echartsgl', 'china'],function(ec){
#     var myChart = ec.init(document.getElementById('2017-08-03 09:58:10.844299'));
#                var option =  {
#     "tooltip": {},
#     "toolbox": {
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true
#             }
#         },
#         "top": "center",
#         "orient": "vertical",
#         "left": "right"
#     },
#     "backgroundColor": "#fff",
#     "series": [
#         {
#             "name": "",
#             "label": {
#                 "emphasis": {
#                     "show": true
#                 },
#                 "normal": {
#                     "formatter": null,
#                     "show": false,
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "data": [
#                 [
#                     56,
#                     32,
#                     98
#                 ],
#                 [
#                     27,
#                     53,
#                     27
#                 ],
#                 [
#                     48,
#                     17,
#                     16
#                 ],
#                 [
#                     14,
#                     93,
#                     41
#                 ],
#                 [
#                     56,
#                     27,
#                     63
#                 ],
#                 [
#                     10,
#                     56,
#                     32
#                 ],
#                 [
#                     99,
#                     92,
#                     61
#                 ],
#                 [
#                     20,
#                     78,
#                     20
#                 ],
#                 [
#                     51,
#                     93,
#                     93
#                 ],
#                 [
#                     4,
#                     96,
#                     73
#                 ],
#                 [
#                     33,
#                     36,
#                     90
#                 ],
#                 [
#                     44,
#                     9,
#                     57
#                 ],
#                 [
#                     66,
#                     69,
#                     94
#                 ],
#                 [
#                     92,
#                     74,
#                     21
#                 ],
#                 [
#                     60,
#                     10,
#                     36
#                 ],
#                 [
#                     50,
#                     44,
#                     9
#                 ],
#                 [
#                     87,
#                     41,
#                     21
#                 ],
#                 [
#                     69,
#                     73,
#                     12
#                 ],
#                 [
#                     53,
#                     53,
#                     99
#                 ],
#                 [
#                     77,
#                     35,
#                     59
#                 ],
#                 [
#                     71,
#                     90,
#                     52
#                 ],
#                 [
#                     13,
#                     96,
#                     4
#                 ],
#                 [
#                     26,
#                     59,
#                     33
#                 ],
#                 [
#                     56,
#                     97,
#                     64
#                 ],
#                 [
#                     70,
#                     39,
#                     59
#                 ],
#                 [
#                     94,
#                     36,
#                     7
#                 ],
#                 [
#                     83,
#                     66,
#                     15
#                 ],
#                 [
#                     6,
#                     69,
#                     91
#                 ],
#                 [
#                     89,
#                     43,
#                     94
#                 ],
#                 [
#                     87,
#                     71,
#                     78
#                 ],
#                 [
#                     81,
#                     90,
#                     62
#                 ],
#                 [
#                     71,
#                     58,
#                     73
#                 ],
#                 [
#                     9,
#                     52,
#                     16
#                 ],
#                 [
#                     10,
#                     83,
#                     30
#                 ],
#                 [
#                     15,
#                     17,
#                     33
#                 ],
#                 [
#                     84,
#                     85,
#                     6
#                 ],
#                 [
#                     5,
#                     91,
#                     33
#                 ],
#                 [
#                     47,
#                     19,
#                     33
#                 ],
#                 [
#                     62,
#                     58,
#                     28
#                 ],
#                 [
#                     93,
#                     1,
#                     32
#                 ],
#                 [
#                     75,
#                     91,
#                     44
#                 ],
#                 [
#                     6,
#                     33,
#                     62
#                 ],
#                 [
#                     45,
#                     62,
#                     95
#                 ],
#                 [
#                     58,
#                     13,
#                     52
#                 ],
#                 [
#                     72,
#                     97,
#                     33
#                 ],
#                 [
#                     100,
#                     14,
#                     92
#                 ],
#                 [
#                     65,
#                     28,
#                     8
#                 ],
#                 [
#                     76,
#                     15,
#                     15
#                 ],
#                 [
#                     68,
#                     21,
#                     91
#                 ],
#                 [
#                     55,
#                     19,
#                     64
#                 ],
#                 [
#                     29,
#                     32,
#                     66
#                 ],
#                 [
#                     93,
#                     27,
#                     37
#                 ],
#                 [
#                     6,
#                     10,
#                     34
#                 ],
#                 [
#                     81,
#                     74,
#                     64
#                 ],
#                 [
#                     90,
#                     26,
#                     60
#                 ],
#                 [
#                     52,
#                     20,
#                     52
#                 ],
#                 [
#                     80,
#                     2,
#                     41
#                 ],
#                 [
#                     46,
#                     16,
#                     39
#                 ],
#                 [
#                     55,
#                     61,
#                     89
#                 ],
#                 [
#                     39,
#                     27,
#                     43
#                 ],
#                 [
#                     43,
#                     53,
#                     38
#                 ],
#                 [
#                     68,
#                     53,
#                     12
#                 ],
#                 [
